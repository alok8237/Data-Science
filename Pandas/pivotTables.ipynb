# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pivot tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': [
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South'
    ],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': [
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice'
    ]
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    344     85   John  January      Q1
# 1  2023-01-02       B   West    322     42   Mary  January      Q1
# 2  2023-01-03       C  North    389     65    Bob  January      Q1
# 3  2023-01-04       D  South    311     45  Alice  January      Q1
# 4  2023-01-05       A   East    647     72   John  January      Q1
# 5  2023-01-06       B   West    603     95   Mary  January      Q1
# 6  2023-01-07       C  North    583     93    Bob  January      Q1
# 7  2023-01-08       D  South    998     39  Alice  January      Q1
# 8  2023-01-09       A   East    945     36   John  January      Q1
# 9  2023-01-10       B   West    449     84   Mary  January      Q1
# 10 2023-01-11       C  North    683     13    Bob  January      Q1
# 11 2023-01-12       D  South    243     43  Alice  January      Q1
# 12 2023-01-13       A   East    827     99   John  January      Q1
# 13 2023-01-14       B   West    223     24   Mary  January      Q1
# 14 2023-01-15       C  North    941     50    Bob  January      Q1
# 15 2023-01-16       D  South    159     36  Alice  January      Q1
# 16 2023-01-17       A   East    731     33   John  January      Q1
# 17 2023-01-18       B   West    762     94   Mary  January      Q1
# 18 2023-01-19       C  North    854     10    Bob  January      Q1
# 19 2023-01-20       D  South    560     41  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product")
# Out:
# Product      A      B      C      D
# Region
# East     698.8    NaN    NaN    NaN
# North      NaN    NaN  690.0    NaN
# South      NaN    NaN    NaN  454.2
# West       NaN  471.8    NaN    NaN

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product",aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     731.0    NaN    NaN    NaN
# North      NaN    NaN  683.0    NaN
# South      NaN    NaN    NaN  311.0
# West       NaN  449.0    NaN    NaN

# %%
pd.pivot_table(df,values=["Sales","Units"],index="Region",columns="Product",aggfunc='median')
#values must be numeric
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     731.0    NaN    NaN    NaN  72.0   NaN   NaN   NaN
# North      NaN    NaN  683.0    NaN   NaN   NaN  50.0   NaN
# South      NaN    NaN    NaN  311.0   NaN   NaN   NaN  41.0
# West       NaN  449.0    NaN    NaN   NaN  84.0   NaN   NaN

# %% [markdown]
# **Cross tabs**

# %%
pd.crosstab(df['Region'],df['Product'])
#used for counting purpose
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
